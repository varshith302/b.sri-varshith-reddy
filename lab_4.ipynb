# %% [markdown]
# <a href="https://colab.research.google.com/github/varshith302/b.sri-varshith-reddy/blob/main/lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
file_path = '/content/Iris.csv'
df = pd.read_csv(file_path)
df.isna().sum()

X=df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
X_scale = StandardScaler()
X_scaled = X_scale.fit_transform(X)
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
pca_df['Target'] = y

plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue=pca_df['Target'], palette='viridis', data=pca_df)
plt.title('PCA: Dimensionality Reduction to 2D')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Target')
plt.show()
