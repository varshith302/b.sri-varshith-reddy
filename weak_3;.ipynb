# %% [markdown]
# <a href="https://colab.research.google.com/github/varshith302/b.sri-varshith-reddy/blob/main/weak_3%3B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
file_path = "Iris.csv"
df = pd.read_csv(file_path)
features = df.drop(columns=["Id", "Species"])
labels = df["Species"]
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)
pca = PCA(n_components=2)
pca_features = pca.fit_transform(features_scaled)
pca_df = pd.DataFrame(data=pca_features, columns=["PC1", "PC2"])
pca_df["Species"] = labels
plt.figure(figsize=(8, 6))
sns.scatterplot(x="PC1", y="PC2", hue="Species", data=pca_df, palette="Set1")
plt.title("PCA: Iris Dataset Reduced to 2D")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()
plt.show()
